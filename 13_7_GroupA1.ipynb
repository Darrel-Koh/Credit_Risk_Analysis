# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/credit-risk-analysis/data.csv')
# Out:
# /tmp/ipykernel_32/1106279901.py:1: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/kaggle/input/credit-risk-analysis/data.csv')

# %%
# df.info()

# %%
columns_to_remove = ['title','desc','emp_title','mths_since_last_delinq','mths_since_last_record', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m' ,'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m']

df.drop(columns_to_remove, axis=1, inplace=True)

# %%
df['collections_12_mths_ex_med'].unique()
# Out:
# array([ 0., nan,  1.,  2.,  3.,  4.,  6., 16., 20.,  5.,  7., 10., 14.])

# %%
missing_values = df.isnull().any() 
missing_values
# Out:
# id                            False
# member_id                     False
# loan_amnt                     False
# funded_amnt                   False
# funded_amnt_inv               False
# term                          False
# int_rate                      False
# installment                   False
# grade                         False
# sub_grade                     False
# emp_length                     True
# home_ownership                False
# annual_inc                    False
# verification_status           False
# issue_d                       False
# pymnt_plan                    False
# purpose                       False
# zip_code                      False
# addr_state                    False
# dti                           False
# delinq_2yrs                   False
# earliest_cr_line              False
# inq_last_6mths                False
# open_acc                      False
# pub_rec                       False
# revol_bal                     False
# ...
